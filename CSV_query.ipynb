# %%
import requests
import pandas as pd
import pprint

# %%
pa_data = pd.read_csv('WDPA_Aug2024_Public_csv.csv')
pd.set_option('display.max_columns', None)
pa_data.head(2)
# Out:
# /var/folders/w5/fwg8f9x10l7c0qrg0fkklg9w0000gn/T/ipykernel_12470/948895624.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   pa_data = pd.read_csv('WDPA_Aug2024_Public_csv.csv')
#       TYPE     WDPAID   WDPA_PID  PA_DEF             NAME        ORIG_NAME  \
# 0  Polygon  555645336  555645336       1     Pangasananan     Pangasananan
# 1  Polygon  555645495  555645495       1  Inuyog No Banwa  Inuyog No Banwa
#
#              DESIG          DESIG_ENG      DESIG_TYPE IUCN_CAT  \
# 0     Pangasananan   Ancestral Domain  Not Applicable       VI
# 1  Inuyog No Banwa  Conserved habitat  Not Applicable       VI
#
#          INT_CRIT  MARINE  REP_M_AREA  GIS_M_AREA  REP_AREA   GIS_AREA  \
# 0  Not Applicable       0         0.0         0.0     69.96  69.500970
# 1  Not Applicable       0         0.0         0.0     97.89  97.254113
#
#           NO_TAKE  NO_TK_AREA       STATUS  STATUS_YR  \
# ...

# %%
pa_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 304747 entries, 0 to 304746
# Data columns (total 31 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   TYPE         304747 non-null  object
#  1   WDPAID       304747 non-null  int64
#  2   WDPA_PID     304747 non-null  object
#  3   PA_DEF       304747 non-null  int64
#  4   NAME         304747 non-null  object
#  5   ORIG_NAME    304747 non-null  object
#  6   DESIG        304747 non-null  object
#  7   DESIG_ENG    304747 non-null  object
#  8   DESIG_TYPE   304747 non-null  object
#  9   IUCN_CAT     304747 non-null  object
#  10  INT_CRIT     304747 non-null  object
#  11  MARINE       304747 non-null  int64
#  12  REP_M_AREA   304747 non-null  float64
#  13  GIS_M_AREA   292716 non-null  float64
#  14  REP_AREA     304747 non-null  float64
#  15  GIS_AREA     292716 non-null  float64
#  16  NO_TAKE      303188 non-null  object
#  17  NO_TK_AREA   304747 non-null  float64
# ...

# %%
grouped_pas = pa_data.groupby(['ISO3', 'STATUS'])
# pd.set_option('display.max_rows', None)
grouped_pas

# %%
df = pd.DataFrame()

df['total_area'] = grouped_pas['GIS_M_AREA'].sum()
df.reset_index()

df
# Out:
#                                                                 total_area
# ISO3                                            STATUS
# ABNJ                                            Designated    2.659464e+06
# ABW                                             Designated    2.651420e-02
# AFG                                             Designated    0.000000e+00
#                                                 Proposed      0.000000e+00
# AGO                                             Designated    6.624028e+01
#                                                 Proposed      9.145133e+03
# AIA                                             Designated    7.267474e+01
# ALA                                             Designated    6.828092e+02
# ALB                                             Adopted       1.144763e+02
#                                                 Designated    3.937862e+02
# AND                                             Designated    0.000000e+00
# ...

# %%
pa_status.dtype
# Out:
# dtype('float64')
